# %%
pip install langchain-community duckduckgo-search
# Out:
# Requirement already satisfied: langchain-community in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: duckduckgo-search in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (8.1.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (1.1.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (0.4.59)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: certifi in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: click>=8.1.8 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from duckduckgo-search) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from duckduckgo-search) (6.0.2)
# Requirement already satisfied: colorama in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U ddgs
# Out:
# Requirement already satisfied: ddgs in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (9.9.3)
# Requirement already satisfied: click>=8.1.8 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from ddgs) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=4.9.4 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: colorama in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.12.0)
# Requirement already satisfied: certifi in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Requirement already satisfied: socksio==1.* in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\91811\desktop\langgraph\sentiment_router\.venv\lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime
from typing import TypedDict, List, Dict, Optional
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langgraph.graph import StateGraph, END

# --- 1. CONFIGURATION ---
# Using Qwen 2.5 (0.5B)
llm = ChatOllama(model="qwen2.5:0.5b", temperature=0)

# --- 2. DEFINE STATE ---
class PlannerState(TypedDict):
    subjects: List[str]
    total_hours: float
    difficulty_map: str       # Stores the "Hard/Easy" analysis
    schedule_text: str        # The final timetable
    resources: List[str]      # The YouTube links
    quality_score: int        # 0-10 rating
    feedback: str             # Auditor notes

# --- 3. DEFINE NODES ---

def difficulty_analyzer_node(state: PlannerState):
    """
    Agent 1: The Strategist.
    Decides which subject is Hard or Easy.
    """
    print(f"🧠 Strategist: Analyzing difficulty for {state['subjects']}...")
    
    prompt = ChatPromptTemplate.from_template(
        """Analyze these subjects: {subjects}.
        Assign 'Hard', 'Medium', or 'Easy' to each.
        Return ONLY a simple list like: Math: Hard, Art: Easy.
        """
    )
    chain = prompt | llm
    response = chain.invoke({"subjects": state['subjects']})
    
    return {"difficulty_map": response.content}

def scheduler_node(state: PlannerState):
    """
    Agent 2: The Architect.
    Creates the table.
    """
    now = datetime.datetime.now().strftime("%I:%M %p")
    print(f"📅 Architect: Building schedule starting at {now}...")
    
    # We explicitly ask for a Markdown Table here
    prompt = ChatPromptTemplate.from_template(
        """You are a strict scheduler.
        Current Time: {current_time}
        Total Hours: {hours}
        Difficulty: {diff_map}
        Subjects: {subjects}
        
        Task: Create a study schedule in a Markdown Table format.
        Columns: [Time Slot] | [Subject] | [Activity/Topic]
        
        Rules:
        1. Start exactly at {current_time}.
        2. Include 10-minute breaks between subjects.
        3. Do not chat. Output ONLY the table.
        """
    )
    
    chain = prompt | llm
    response = chain.invoke({
        "current_time": now,
        "hours": state['total_hours'],
        "subjects": state['subjects'],
        "diff_map": state['difficulty_map']
    })
    
    return {"schedule_text": response.content}

def resource_generator_node(state: PlannerState):
    """
    Agent 3: The Librarian (Fixed).
    Generates YouTube links instead of searching text snippets.
    """
    print("🔗 Librarian: Generating YouTube links...")
    subjects = state["subjects"]
    links = []
    
    for sub in subjects:
        # Create a clickable YouTube Search URL
        query = sub.replace(" ", "+")
        url = f"https://www.youtube.com/results?search_query={query}+tutorial"
        links.append(f"📺 **{sub}**: {url}")
            
    return {"resources": links}

def auditor_node(state: PlannerState):
    """
    Agent 4: The Critic.
    """
    print("⚖️ Auditor: Checking table formatting...")
    plan = state["schedule_text"]
    
    # Check if it actually looks like a table
    if "|" in plan and "-" in plan:
        score = 9
    else:
        score = 4
        
    print(f"   Score: {score}/10")
    
    if score < 6:
        return {"quality_score": score, "feedback": "Output was not a table."}
    return {"quality_score": score, "feedback": "Approved"}

# --- 4. ROUTER LOGIC ---

def route_auditor(state: PlannerState):
    if state["quality_score"] < 6:
        print("   ❌ Retrying schedule...")
        return "scheduler"
    else:
        print("   ✅ Schedule Approved!")
        return "resource_generator"

# --- 5. BUILD GRAPH ---

workflow = StateGraph(PlannerState)

workflow.add_node("strategist", difficulty_analyzer_node)
workflow.add_node("scheduler", scheduler_node)
workflow.add_node("auditor", auditor_node)
workflow.add_node("resource_generator", resource_generator_node)

workflow.set_entry_point("strategist")
workflow.add_edge("strategist", "scheduler")
workflow.add_edge("scheduler", "auditor")

workflow.add_conditional_edges(
    "auditor",
    route_auditor,
    {
        "scheduler": "scheduler",
        "resource_generator": "resource_generator"
    }
)

workflow.add_edge("resource_generator", END)

app = workflow.compile()

# --- 6. RUN IT ---

inputs = {
    "subjects": ["Machine Learning", "Linear Algebra"],
    "total_hours": 3
}

final_state = app.invoke(inputs, config={"recursion_limit": 10})

print("\n" + "="*40)
print("       🎓 YOUR STUDY PLAN 🎓")
print("="*40 + "\n")

print(f"📊 Analysis:\n{final_state['difficulty_map']}\n")
print(f"🗓️ TIMETABLE:\n{final_state['schedule_text']}\n")
print("-" * 30)
print("🌍 RESOURCES:")
for res in final_state['resources']:
    print(res)
# Out:
# 🧠 Strategist: Analyzing difficulty for ['Machine Learning', 'Linear Algebra']...
# 📅 Architect: Building schedule starting at 11:01 PM...
# ⚖️ Auditor: Checking table formatting...
#    Score: 9/10
#    ✅ Schedule Approved!
# 🔗 Librarian: Generating YouTube links...
#
# ========================================
#        🎓 YOUR STUDY PLAN 🎓
# ========================================
#
# 📊 Analysis:
# Math: Hard, Art: Medium.
#
# 🗓️ TIMETABLE:
# | Time Slot | Subject   | Activity/Topic |
# |-----------|----------|-----------------|
# | 11:01    | Machine Learning | Linear Algebra     |
# | 11:02    | Math       | Calculus          |
# | 11:03    | Physics    | Quantum Mechanics |
# | 11:04    | History    | World History      |
# | 11:05    | Art        | Painting         |
# | 11:06    | Music      | Classical Music  |
# | 11:07    | Science   | Biology          |
# | 11:08    | English   | Literature       |
# | 11:09    | History  | World History     |
# | 11:10    | Art        | Painting         |
# | 11:11    | Music      | Classical Music  |
# | 11:12    | Science   | Biology          |
# | 11:13    | English   | Literature       |
# | 11:14    | History  | World History     |
# | 11:15    | Art        | Painting         |
# | 11:16    | Music      | Classical Music  |
# | 11:17    | Science   | Biology          |
# | 11:18    | English   | Literature       |
# | 11:19    | History  | World History     |
# | 11:20    | Art        | Painting         |
# | 11:21    | Music      | Classical Music  |
# | 11:22    | Science   | Biology          |
# | 11:23    | English   | Literature       |
# | 11:24    | History  | World History     |
# | 11:25    | Art        | Painting         |
# | 11:26    | Music      | Classical Music  |
# | 11:27    | Science   | Biology          |
# | 11:28    | English   | Literature       |
# | 11:29    | History  | World History     |
# | 11:30    | Art        | Painting         |
# | 11:31    | Music      | Classical Music  |
# | 11:32    | Science   | Biology          |
# | 11:33    | English   | Literature       |
# | 11:34    | History  | World History     |
# | 11:35    | Art        | Painting         |
# | 11:36    | Music      | Classical Music  |
# | 11:37    | Science   | Biology          |
# | 11:38    | English   | Literature       |
# | 11:39    | History  | World History     |
# | 11:40    | Art        | Painting         |
# | 11:41    | Music      | Classical Music  |
# | 11:42    | Science   | Biology          |
# | 11:43    | English   | Literature       |
# | 11:44    | History  | World History     |
# | 11:45    | Art        | Painting         |
# | 11:46    | Music      | Classical Music  |
# | 11:47    | Science   | Biology          |
# | 11:48    | English   | Literature       |
# | 11:49    | History  | World History     |
# | 11:50    | Art        | Painting         |
# | 11:51    | Music      | Classical Music  |
# | 11:52    | Science   | Biology          |
# | 11:53    | English   | Literature       |
# | 11:54    | History  | World History     |
# | 11:55    | Art        | Painting         |
# | 11:56    | Music      | Classical Music  |
# | 11:57    | Science   | Biology          |
# | 11:58    | English   | Literature       |
# | 11:59    | History  | World History     |
# | 12:00    | Art        | Painting         |
# | 12:01    | Music      | Classical Music  |
#
# Please note that the table is not complete because there are no more subjects listed.
#
# ------------------------------
# 🌍 RESOURCES:
# 📺 **Machine Learning**: https://www.youtube.com/results?search_query=Machine+Learning+tutorial
# 📺 **Linear Algebra**: https://www.youtube.com/results?search_query=Linear+Algebra+tutorial
